# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaShreeram/Analyzing_spectra_with_ML/blob/master/08_%5BCase_D%5D_NNs_on_light_curves_with_GPR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## {**Case D**}  Deep learning using NNs with microlensing curves ***with Season Gaps and Gaussian Processes Regression (GPR)***
#
# The following notebook tests NNs on microlensed light curves that do not contain season gaps. The notebook contains the following sections:
# 1. Input parameters
# 2. Loading data <br>
#   i. Plotting light curves
# 3. Generations of training and testing data sets
# 4. Compiling the 3 networks (can choose one of them for training) <br>
#   i. CNN <br>
#   ii. ResNet-7 <br>
#   iii. ResNet-18
# 5. Training the network on the optimized parameters <br>
#   i. Plotting loss-accuracy curves <br>
#   ii. Displaying the confusioni matrix
#
#
# **Author**: Soumya Shreeram <br>
# **Script adapted from**: Millon Martin & Kevin Müller <br>
# **Date**: 15th May 2020

# %% [markdown]
# Import all required python libraries

# %%
from google.colab import drive
import os
import pickle
import importlib
import itertools

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import random
import os
from IPython.display import Image, SVG
from scipy.interpolate import interp1d 

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import sklearn.gaussian_process as gp
from sklearn.gaussian_process.kernels import RBF, Matern, WhiteKernel, RationalQuadratic
from sklearn.gaussian_process.kernels import ConstantKernel

# %tensorflow_version 1.x
import tensorflow as tf

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Activation, InputSpec
from tensorflow.python.keras.layers import Conv1D, Conv2D
from tensorflow.python.keras.layers import MaxPooling1D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Add, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Mount google drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Directory where the `python` files are stored on Google Drive. The `.py` files that are imported must be in the same working directory (nb stands for notebook). To reload the imported files - if you have made any changes to them - use `importlib.reload(short_name_for_the_imported_py_file); eg. dat or nnet` .

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks')

import nb_02i_preprocessing_data as dat
import nb_03_neural_network_designs as nnet

# %% [markdown]
# Setting up the path to the data directory

# %%
current_dir = os.getcwd()
data_dir = r'/content/gdrive/My Drive/training_set_microlensing/'
save_image_dir = r'/content/gdrive/My Drive/Colab Notebooks/Images/'
save_model_dir = r'/content/gdrive/My Drive/Colab Notebooks/Models/'
save_data_dir = r'/content/gdrive/My Drive/Colab Notebooks/Data/'

# %% [markdown]
# ### 1. Input parameters
#
# The scale radius used here is in pixels, where 1 pixel = 0.67 $R_{\rm ref}$; $R_{\rm ref} = 0.048 \ R_{\rm E}$ is the reference radius for QSO $J0158$ that is borrowed from [Mosquera & Kochanek (2011)](https://iopscience.iop.org/article/10.1088/0004-637X/738/1/96/pdf).

# %%
v_t = [500, 300] # transverse velcity
v_t_idx = 0 # choose index value for the velocity you would like (0 or 1)
r_0 = (2,4,10,15,20,30,40,60,80,100) # scale radius
output_class_names = [str(r) for r in r_0 ]

# select type of Interpolation
cubic, linear = False, True

# data loaded with season gaps
season_gaps = True

# if using the new data set generated by Eric (v_500_new, v_500_gaps_new)
new_data_set = True

# generates new interpolated light curves? OR Use previously saved light curves?
generate_new_files, use_saved_file = False, True

# %% [markdown]
# If using the `new_data_set`, make sure to have the `numLcurvesPerRadius...npy` file in the `v_x00` folder. This file contains the *number of light curves per radius, total curves, number of samples, etc* such that one does not need to hard-code the parameters when opening the files, whose names contain such variable. See more details on how it is read in the imported file `nb_02i_preprocessing_data.py`.

# %% [markdown]
# ### 2. Load the data

# %% [markdown]
# There are 10 categories into which the light-curves are classified. Each category is represented by the scale radius `r_0`. The light-curves corresponding to each `r_0` are collectively stored in the 3D array `l_curves` whose shape corresponds to `= (num_features, num_samples, 1)`

# %%
# sets the sampling parameters
sample_params = dat.setSamplingParameters(v_t[v_t_idx], data_dir, season_gaps)

# initializes data arrays
class_cat, l_curves, out_catergories, out_radii = dat.initializer(r_0, \
                                                                  sample_params)

for idx, rad in enumerate(r_0):
  filename = dat.getFilename(data_dir, idx, rad, v_t[v_t_idx], sample_params, \
                             season_gaps, new_data_set)
  
  # load data from the file
  l_curves, mjhd, mjhd_err = dat.loadData(filename, idx, l_curves, sample_params, idx,\
                                  season_gaps, new_data_set)
  out_catergories[idx*sample_params[0][idx]:(idx+1)*sample_params[0][idx]] = class_cat[1][idx]
  out_radii[idx*sample_params[0][idx]:(idx+1)*sample_params[0][idx]] = r_0[idx]

print('Shape of light curves vector:', np.shape(l_curves))
# Out:
# Shape of light curves vector: (50000, 955, 1)

# %% [markdown]
# #### 2.1 Load the light curves interpolated using Gaussian Processes

# %%
# initializing a light curve array to store the gaussian proccesses regressed curves
l_curves_gpr = np.array([])
l_curves_gpr.shape = (0, len(l_curves[0,:,0]),1)

# loads the file
filename = 'Light_Curves/lcurves_SeasonGaps_GPR_%d'%len(l_curves)
l_curves_gpr = dat.loadFile(data_dir,filename)

# prints the light curves shape
dat.printLcurvesShape(l_curves_gpr)
# Out:
# shape of light curves arrays: (50000, 955, 1)

# %% [markdown]
# #### 2.2 Plots of some random light-curves

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,5))
n = [9999, 2600]
colors = ['#127a00',  '#00727a', '#888894']

# original and reshuffled time-array
mjhd = np.load(data_dir+'Light_Curves/mjhd.npy')
mjhd_gpr = np.linspace(mjhd[0], mjhd[-1], num=len(mjhd))

for i, num in enumerate(n):
  # light curves with GP interpolation
  ax.plot(mjhd_gpr, l_curves_gpr[n[i], :, 0], '.', color='k', label='GPR interpolation', markersize=2)

  # without interpolation
  ax.plot(mjhd, l_curves[n[i], :], '.', color=colors[i], label='Radius: %i'%(out_radii[n[i]]), markersize=8)

dat.setLabels(ax, 'HJD (days)', 'Magnitude', ticks=True, legend=True)
fig.savefig(save_image_dir+'/interpolated_lcurves.png') 

print(out_radii[9900], out_radii[2600])
# Out:
# 4.0 2.0

# %% [markdown]
# ### 4. Generate training and testing data sets
#
# Proceeding with linear interpolation.

# %%
train_l_curves, test_l_curves, onehot_train, onehot_test, train_radii, \
test_radii  = dat.generateTestTrain(l_curves_gpr, out_catergories, out_radii, r_0)

trainX, trainy, testX, testy = train_l_curves, onehot_train, test_l_curves, onehot_test

# %% [markdown]
# ### 4. Compiling the 3 networks
#
# The three networks compiled here are coded in `nb04_Neural_Network_Designs.py`. These `.py` files can be found in the GitHub repository.
#
# Note that if you are running this from colab, need to have these `.py` files in your drive folder *Colab Notebooks*.
#
# The three networks are the Convolutional Neural Network (**CNN**), Residual Neural Network with 7 layers (**ResNet7**), and the Residual Neural Network with 18 layers (**ResNet18**). Refer to the report for more detailed information about the neural network stuctures.

# %% [markdown]
# Default constants that can be modified.

# %%
# choose one of these networks to use by setting the boolean to True and rest to False
CNN, ResNet7, ResNet18 = False, True, False

model_types = [CNN, ResNet7, ResNet18]
model_name_list = ['CNN','ResNet7', 'ResNet18']

for i in range(len(model_name_list)):
  if model_types[i]:
    model_name = model_name_list[i]
print('Using the Neural Network:', model_name)
# Out:
# Using the Neural Network: ResNet7

# %% [markdown]
# The following code block uses the methods defined in the file `dr04_Neural_Network_Designs.py`: imported as **`nnet`**
#
# Model parameters are defined in the methods in **`nnet`** additionally some more details:
# * `num_hidden_nodes`: number of nodes in hidden fully connected layer
# *`dropout_ratio`: % of nodes in the hidden layer to dropout during back-propagation update of the network weights

# %% [markdown]
# #### 4.1 Compiling CNN

# %%
if CNN:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # CNN model parameters
  num_filter = (32, 32, 44, 44)
  kern_size = (21,21,15,15)
  maxpoolsize = (None, 15, None, 15)
  shortcut_link = (0,1,2,3)
  batch_norm = False
  dropout_ratio = 0.4  
  sampling = 3
  num_pieces = 1
  num_hidden_nodes = 1500
  
  # build the model
  inputs, outputs = nnet.buildCNN(sample_params[2], num_filter, kern_size, maxpoolsize, \
                                  num_hidden_nodes, dropout_ratio, r_0)
  
  # optimization, compilation parameters
  optimizer_type = Adam(lr=5e-4)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles the model
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                    metrics, save_image_dir+'CNN', True)
    
  print('Network created')

# %% [markdown]
# #### 4.2 Compiling ResNet-7

# %%
if ResNet7:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # CNN model parameters
  num_filter = (32, 32, 44, 44)
  kern_size = (21,21,15,15)
  maxpoolsize = (None, 15, None, 15)
  shortcut_link = (0,1,2,3)
  batch_norm = False
  dropout_ratio = 0.4  
  sampling = 3
  num_pieces = 1
  num_hidden_nodes = [1500]
  
  # prepare data with sample cuts with the correct shape
  testX_prep = nnet.prepareDataSampleCuts(testX, sampling, num_pieces)
  trainX_prep = nnet.prepareDataSampleCuts(trainX, sampling, num_pieces)

  # build the model
  inputs, outputs = nnet.buildResNet7(num_filter, kern_size, \
                                                  maxpoolsize, num_hidden_nodes[0], \
                                                  dropout_ratio, shortcut_link, \
                                                  batch_norm, trainX_prep.shape[1], r_0)
  
  # optimization, compilation parameters
  optimizer_type = Adam(lr=5e-4)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles the model
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                    metrics, save_image_dir+'ResNet-7', do_print_summary = False)
    
  print('Network created')
# Out:
# reshaped data (319,)
# reshaped data (319,)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:4277: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7fe8619a5978>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7fe8619a5978>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# Network created

# %% [markdown]
# ### 4.3 Compiling ResNet-18

# %%
if ResNet18:
  # reloads the file if any changes are made
  importlib.reload(nnet)

  # ResNet model parameters
  num_filter = (32, 32, 32)
  kern_size = (10,20,50)
  n_block = 5
  maxpoolsize = 3
  num_hidden_nodes =[1000.0,]
  dropout_ratio = 0.7 
  batch_norm = True
  sampling = 1
  num_pieces = 1

  # build network
  inputs, outputs = nnet.buildResNet18(sample_params[2], num_filter, kern_size, n_block, \
                                 maxpoolsize, num_hidden_nodes, dropout_ratio, r_0,\
                                 batch_norm)
  
  # ResNet compilation parameters
  learning_rate = 1e-4
  max_epochs = 80
  decay = learning_rate/max_epochs
  optimizer_type = Adam(lr=learning_rate, decay=decay)  
  loss = 'categorical_crossentropy'  
  metrics = ['categorical_accuracy'] 

  # compiles network
  model = nnet.compileDisplayNetwork(inputs, outputs, optimizer_type, loss, \
                                     metrics,save_image_dir+'ResNet-18', True)
  
  #model.load_weights('/content/gdrive/My Drive/Colab_Notebooks/Deep_learning_for_optical_IMaging/Resnet_weights.h5')
  print('Network created')
# Out:
# WARNING:tensorflow:Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7efc40486240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method GlobalMaxPoolingSp2D.call of <nb_03_neural_network_designs.GlobalMaxPoolingSp2D object at 0x7efc40486240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 955, None, 1 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 955, None, 32 352         input_3[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 955, None, 32 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 955, None, 32 20512       activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 955, None, 32 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 955, None, 32 51232       activation_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 955, None, 32 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 955, None, 32 0           activation_25[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 477, None, 32 0           add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 477, None, 32 128         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 477, None, 32 10272       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 477, None, 32 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 477, None, 32 20512       activation_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 477, None, 32 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 477, None, 32 51232       activation_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 477, None, 32 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 477, None, 32 0           activation_28[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 238, None, 32 0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 238, None, 32 128         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 238, None, 32 10272       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 238, None, 32 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 238, None, 32 20512       activation_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 238, None, 32 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 238, None, 32 51232       activation_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 238, None, 32 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 238, None, 32 0           activation_31[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 118, None, 32 0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 118, None, 32 128         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 118, None, 32 10272       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 118, None, 32 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 118, None, 32 20512       activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 118, None, 32 0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 118, None, 32 51232       activation_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 118, None, 32 0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 118, None, 32 0           activation_34[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 58, None, 32) 0           add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 58, None, 32) 128         max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 58, None, 32) 10272       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 58, None, 32) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 58, None, 32) 20512       activation_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 58, None, 32) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 58, None, 32) 51232       activation_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 58, None, 32) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 58, None, 32) 0           activation_37[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 28, None, 32) 0           add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, None, 32) 128         max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling_sp2d_2 (Glob (None, 28, 32)       0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 896)          0           global_max_pooling_sp2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1000)         897000      flatten_2[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 1000)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1000)         0           activation_38[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           10010       dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 10)           0           dense_5[0][0]
# ==================================================================================================
# Total params: 1,307,810
# Trainable params: 1,307,490
# Non-trainable params: 320
# __________________________________________________________________________________________________
# None
# Network created

# %% [markdown]
# ### 5. Training the network
#
# Constants used for training the network

# %%
validation_split_ratio = 0.2  # % of the seen dataset to be put aside for validation, rest is for training
max_epochs = 50  # maxmimum number of epochs to be iterated
batch_size = 60   # batch size for the training data set
num_inputs = 1
verbose = 1

# %%
if ResNet7:
  # reshaped data is used while training
  trainX = trainX_prep
  testX = testX_prep

# trains the model
model, model_history = nnet.trainModel(model, trainX, trainy, batch_size, max_epochs,\
                                  validation_split_ratio, verbose)

# evaluates and predicts the results from the trained model
results, predictions = nnet.evaluatePredictModel(model, testX, testy, verbose = 1) 

print('[test loss, test acc] = ', results)
# Out:
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/50
# 32000/32000 [==============================] - 9s 281us/sample - loss: 1.9181 - categorical_accuracy: 0.2553 - val_loss: 1.7047 - val_categorical_accuracy: 0.3392
# Epoch 2/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.6771 - categorical_accuracy: 0.3419 - val_loss: 1.6024 - val_categorical_accuracy: 0.3830
# Epoch 3/50
# 32000/32000 [==============================] - 3s 78us/sample - loss: 1.6035 - categorical_accuracy: 0.3740 - val_loss: 1.5828 - val_categorical_accuracy: 0.3805
# Epoch 4/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.5521 - categorical_accuracy: 0.3999 - val_loss: 1.5371 - val_categorical_accuracy: 0.4039
# Epoch 5/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.5154 - categorical_accuracy: 0.4136 - val_loss: 1.5005 - val_categorical_accuracy: 0.4214
# Epoch 6/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.4868 - categorical_accuracy: 0.4276 - val_loss: 1.4767 - val_categorical_accuracy: 0.4350
# Epoch 7/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.4646 - categorical_accuracy: 0.4384 - val_loss: 1.4723 - val_categorical_accuracy: 0.4361
# Epoch 8/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.4384 - categorical_accuracy: 0.4506 - val_loss: 1.4838 - val_categorical_accuracy: 0.4297
# Epoch 9/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.4217 - categorical_accuracy: 0.4528 - val_loss: 1.4121 - val_categorical_accuracy: 0.4608
# Epoch 10/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3993 - categorical_accuracy: 0.4655 - val_loss: 1.4272 - val_categorical_accuracy: 0.4572
# Epoch 11/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3875 - categorical_accuracy: 0.4694 - val_loss: 1.4160 - val_categorical_accuracy: 0.4557
# Epoch 12/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3724 - categorical_accuracy: 0.4749 - val_loss: 1.3936 - val_categorical_accuracy: 0.4724
# Epoch 13/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3604 - categorical_accuracy: 0.4770 - val_loss: 1.3920 - val_categorical_accuracy: 0.4645
# Epoch 14/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3484 - categorical_accuracy: 0.4848 - val_loss: 1.3690 - val_categorical_accuracy: 0.4703
# Epoch 15/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.3362 - categorical_accuracy: 0.4866 - val_loss: 1.3698 - val_categorical_accuracy: 0.4746
# Epoch 16/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.3223 - categorical_accuracy: 0.4929 - val_loss: 1.3586 - val_categorical_accuracy: 0.4791
# Epoch 17/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.3163 - categorical_accuracy: 0.4937 - val_loss: 1.3498 - val_categorical_accuracy: 0.4856
# Epoch 18/50
# 32000/32000 [==============================] - 3s 82us/sample - loss: 1.3060 - categorical_accuracy: 0.4978 - val_loss: 1.3399 - val_categorical_accuracy: 0.4843
# Epoch 19/50
# 32000/32000 [==============================] - 3s 83us/sample - loss: 1.2992 - categorical_accuracy: 0.4992 - val_loss: 1.3525 - val_categorical_accuracy: 0.4800
# Epoch 20/50
# 32000/32000 [==============================] - 3s 82us/sample - loss: 1.2837 - categorical_accuracy: 0.5070 - val_loss: 1.3112 - val_categorical_accuracy: 0.4951
# Epoch 21/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.2765 - categorical_accuracy: 0.5066 - val_loss: 1.3086 - val_categorical_accuracy: 0.4961
# Epoch 22/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.2704 - categorical_accuracy: 0.5057 - val_loss: 1.3064 - val_categorical_accuracy: 0.4969
# Epoch 23/50
# 32000/32000 [==============================] - 2s 78us/sample - loss: 1.2605 - categorical_accuracy: 0.5135 - val_loss: 1.2989 - val_categorical_accuracy: 0.5014
# Epoch 24/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.2524 - categorical_accuracy: 0.5138 - val_loss: 1.3257 - val_categorical_accuracy: 0.4922
# Epoch 25/50
# 32000/32000 [==============================] - 2s 77us/sample - loss: 1.2449 - categorical_accuracy: 0.5187 - val_loss: 1.3224 - val_categorical_accuracy: 0.4905
# Epoch 26/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.2393 - categorical_accuracy: 0.5163 - val_loss: 1.2854 - val_categorical_accuracy: 0.5075
# Epoch 27/50
# 32000/32000 [==============================] - 2s 78us/sample - loss: 1.2279 - categorical_accuracy: 0.5228 - val_loss: 1.2647 - val_categorical_accuracy: 0.5163
# Epoch 28/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.2205 - categorical_accuracy: 0.5257 - val_loss: 1.2756 - val_categorical_accuracy: 0.5074
# Epoch 29/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.2187 - categorical_accuracy: 0.5263 - val_loss: 1.2734 - val_categorical_accuracy: 0.5101
# Epoch 30/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.2085 - categorical_accuracy: 0.5287 - val_loss: 1.2861 - val_categorical_accuracy: 0.5056
# Epoch 31/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.2042 - categorical_accuracy: 0.5327 - val_loss: 1.2806 - val_categorical_accuracy: 0.5063
# Epoch 32/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1970 - categorical_accuracy: 0.5371 - val_loss: 1.2627 - val_categorical_accuracy: 0.5120
# Epoch 33/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1912 - categorical_accuracy: 0.5346 - val_loss: 1.2808 - val_categorical_accuracy: 0.5070
# Epoch 34/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1873 - categorical_accuracy: 0.5376 - val_loss: 1.2490 - val_categorical_accuracy: 0.5113
# Epoch 35/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1793 - categorical_accuracy: 0.5412 - val_loss: 1.2500 - val_categorical_accuracy: 0.5166
# Epoch 36/50
# 32000/32000 [==============================] - 3s 82us/sample - loss: 1.1713 - categorical_accuracy: 0.5462 - val_loss: 1.2453 - val_categorical_accuracy: 0.5197
# Epoch 37/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1686 - categorical_accuracy: 0.5458 - val_loss: 1.2438 - val_categorical_accuracy: 0.5155
# Epoch 38/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1639 - categorical_accuracy: 0.5467 - val_loss: 1.2613 - val_categorical_accuracy: 0.5098
# Epoch 39/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1555 - categorical_accuracy: 0.5511 - val_loss: 1.2530 - val_categorical_accuracy: 0.5165
# Epoch 40/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1519 - categorical_accuracy: 0.5499 - val_loss: 1.2314 - val_categorical_accuracy: 0.5282
# Epoch 41/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1480 - categorical_accuracy: 0.5540 - val_loss: 1.2356 - val_categorical_accuracy: 0.5156
# Epoch 42/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1406 - categorical_accuracy: 0.5527 - val_loss: 1.2413 - val_categorical_accuracy: 0.5192
# Epoch 43/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1392 - categorical_accuracy: 0.5537 - val_loss: 1.2440 - val_categorical_accuracy: 0.5161
# Epoch 44/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1355 - categorical_accuracy: 0.5594 - val_loss: 1.2343 - val_categorical_accuracy: 0.5191
# Epoch 45/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1268 - categorical_accuracy: 0.5618 - val_loss: 1.2290 - val_categorical_accuracy: 0.5275
# Epoch 46/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1236 - categorical_accuracy: 0.5593 - val_loss: 1.2358 - val_categorical_accuracy: 0.5239
# Epoch 47/50
# 32000/32000 [==============================] - 3s 79us/sample - loss: 1.1167 - categorical_accuracy: 0.5598 - val_loss: 1.2253 - val_categorical_accuracy: 0.5279
# Epoch 48/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1102 - categorical_accuracy: 0.5656 - val_loss: 1.2395 - val_categorical_accuracy: 0.5194
# Epoch 49/50
# 32000/32000 [==============================] - 3s 81us/sample - loss: 1.1072 - categorical_accuracy: 0.5670 - val_loss: 1.2414 - val_categorical_accuracy: 0.5165
# Epoch 50/50
# 32000/32000 [==============================] - 3s 80us/sample - loss: 1.1079 - categorical_accuracy: 0.5681 - val_loss: 1.2440 - val_categorical_accuracy: 0.5266
# 10000/10000 [==============================] - 1s 61us/sample - loss: 1.2181 - categorical_accuracy: 0.5320
# 10000/10000 [==============================] - 0s 44us/sample
# [test loss, test acc] =  [1.218101506614685, 0.532]

# %%
# plots the history
fig, ax = plt.subplots(1,2, figsize=(14,6))
labels = ['training', 'validation']
loss_Accuracy = ['loss', 'val_loss', 'categorical_accuracy', 'val_categorical_accuracy']

model_history = model_history.history
dat.plotLoss(ax[0], model_history, loss_Accuracy, model_name, labels)
dat.plotAccuracy(ax[1], model_history, loss_Accuracy, model_name, labels)
 
fig.savefig(save_image_dir+'/LandA_GPinter%s_epochs_%d.png'%(model_name, max_epochs))    
fig.tight_layout()

# %%
data = [model_history[loss_Accuracy[0]], model_history[loss_Accuracy[1]], model_history[loss_Accuracy[2]], model_history[loss_Accuracy[3]]]

# saves the loss and accuracy curves
filename = save_data_dir+'SeasonGaps_GP_%s.npy'%model_name
with open(filename, 'wb') as f:
  np.save(f, data, allow_pickle=True)

# %% [markdown]
# ### 6. Displaying the classification report, confusion matrix

# %%
y_predict = np.argmax(predictions, axis=1)
y_test = np.argmax(testy, axis=1)

print('Test set classification report:\n')
print(classification_report(y_test, y_predict, target_names=output_class_names))
# Out:
# Test set classification report:
#
#               precision    recall  f1-score   support
#
#            2       0.84      0.69      0.76       991
#            4       0.70      0.68      0.69      1030
#           10       0.66      0.52      0.58      1017
#           15       0.52      0.57      0.54       972
#           20       0.54      0.62      0.58      1020
#           30       0.47      0.45      0.46       967
#           40       0.45      0.46      0.45       979
#           60       0.41      0.75      0.53      1007
#           80       0.46      0.05      0.09       995
#          100       0.42      0.52      0.46      1022
#
#     accuracy                           0.53     10000
#    macro avg       0.55      0.53      0.51     10000
# weighted avg       0.55      0.53      0.52     10000

# %%
# need this to avoid callback errors
from sklearn.metrics import confusion_matrix
importlib.reload(dat)

# generate confusion matrix
cfm = confusion_matrix(y_test, y_predict)  

# row normalisation of confusion matrix
cfm_probability = cfm.astype('float')/cfm.sum(axis=1)[:, np.newaxis]  
# confusion probability matrix
cfm_probability = cfm_probability * 100.0  

fig, ax = plt.subplots(1,1, figsize=(10,10))
dat.plotConfusionMatrix(ax, cfm_probability, output_class_names, 3)

# save figure
fig.savefig(save_image_dir+'/cfm_%s_epochs_%d_GPInter.png'%(model_name, max_epochs))    
fig.tight_layout()
